# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',1000)

# %%
df=pd.read_csv('raw_data2.csv')
df2=pd.read_csv('merge_data.csv',header=None)

# %%
df.shape
# Out:
# (876, 30)

# %%
df2.shape
# Out:
# (7542, 30)

# %%
df2.columns=df.columns

# %%
df3=pd.concat([df,df2],axis=0)

# %%
df3.head()
# Out:
#   age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  63   F            t                  f                         f    t
# 1  75   F            f                  f                         f    f
# 2  41   F            f                  f                         f    f
# 3  61   M            f                  f                         f    t
# 4  27   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  \
# 0        f               f              f                 f
# 1        f               f              f                 f
# 2        f               f              f                 f
# 3        f               f              f                 f
# 4        f               f              f                 f
#
#   query_hyperthyroid lithium goitre tumor hypopituitary psych TSH_measured  \
# 0                  f       f      f     f             f     f            t
# ...

# %%
df3.shape
# Out:
# (8419, 30)

# %%
df4=pd.read_csv('raw_data3.csv')

# %%
df4.head()
# Out:
#        disease age sex on_thyroxine query_on_thyroxine  \
# 0  hypothyroid  72   M            f                  f
# 1  hypothyroid  15   F            t                  f
# 2  hypothyroid  24   M            f                  f
# 3  hypothyroid  24   F            f                  f
# 4  hypothyroid  77   M            f                  f
#
#   on_antithyroid_medication thyroid_surgery query_hypothyroid  \
# 0                         f               f                 f
# 1                         f               f                 f
# 2                         f               f                 f
# 3                         f               f                 f
# 4                         f               f                 f
#
#   query_hyperthyroid pregnant sick tumor lithium goitre TSH_measured   TSH  \
# 0                  f        f    f     f       f      f            y    30
# 1                  f        f    f     f       f      f            y   145
# ...

# %%
final_df=pd.concat([df3,df4],axis=0,ignore_index=True)

# %%
final_df.head()
# Out:
#   age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  63   F            t                  f                         f    t
# 1  75   F            f                  f                         f    f
# 2  41   F            f                  f                         f    f
# 3  61   M            f                  f                         f    t
# 4  27   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  \
# 0        f               f              f                 f
# 1        f               f              f                 f
# 2        f               f              f                 f
# 3        f               f              f                 f
# 4        f               f              f                 f
#
#   query_hyperthyroid lithium goitre tumor hypopituitary psych TSH_measured  \
# 0                  f       f      f     f             f     f            t
# ...

# %%
final_df.shape
# Out:
# (8570, 30)

# %%
# df3[(df3['disease']=='hyperthyroid') | (df3['disease']=='hypothyroid')]

# %%
final_df[final_df['disease']=='hypothyroid']
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     63   F            t                  f                         f    t
# 2     41   F            f                  f                         f    f
# 3     61   M            f                  f                         f    t
# 4     27   F            f                  f                         f    f
# 8     40   F            f                  f                         f    f
# 10    44   F            f                  f                         f    f
# 11    47   M            f                  f                         f    f
# 12    47   M            f                  f                         f    f
# 13    72   M            f                  f                         f    f
# 14    72   M            f                  f                         f    f
# 15    72   M            f                  f                         f    f
# ...

# %%
final_df.fillna('?')
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     63   F            t                  f                         f    t
# 1     75   F            f                  f                         f    f
# 2     41   F            f                  f                         f    f
# 3     61   M            f                  f                         f    t
# 4     27   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 8565  78   F            f                  f                         f    f
# 8566  69   F            f                  f                         f    f
# 8567   ?   F            f                  f                         f    f
# 8568  30   F            t                  f                         f    f
# 8569  34   F            f                  f                         f    f
#
# ...

# %%
final_df.to_csv('raw_data.csv',index_label='idx')
